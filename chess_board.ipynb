# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# from lecture 10 Jul
grid = np.zeros((8,8,3))
# prints all black board
def render():
    plt.imshow(grid)

# %%
# # test row column logic
# white = (1,1,1)
# grid[1][2]=white
# grid[4][6]=white
# render()

# %%
# from lecture 10 Jul
white = (1,1,1)

# def make_board():

for r in range(8):
    if r%2==0:
        for c in range(8):
            if c%2==0:
                    grid[r][c] = white
    else: 
        for c in range(8):
            if c%2==1:
                grid[r][c] = white
render()

# make_board()

# %%
# from class 10 Jul
class Chessboard:
    def __init__(self):
        self.grid = np.zeros((8,8,3))
        self.red = None
        self.blue = None

        def render():
            plt.imshow(self.grid)

        white = (1,1,1)

        for r in range(8):
            if r%2==0:
                for c in range(8):
                    if c%2==0:
                            self.grid[r][c] = white
            else: 
                for c in range(8):
                    if c%2==1:
                        self.grid[r][c] = white

        # plt.imshow(self.grid)
        render()
    
    def add_red(self, row, col):
        self.grid[row][col] = (.8,.2,0)
        pass

    def add_blue(self, row, col):
        self.grid[row][col] = (0,.6,1)
        pass

    def render(self):
        plt.imshow(self.grid)
        pass

    def is_under_attack(self):
        pass

b = Chessboard()
print(b)
# Out:
# <__main__.Board object at 0x128821ac0>

# %%
# from class 10 Jul
# instantiate new board to clear
board = Chessboard()
board.add_red(1,4)
board.add_blue(5,5)
board.render()
# assert not board.is_under_attack()
# print('******** NOT UNDER ATTACK ********')

# %%
# from class 10 Jul
board = Chessboard()
board.add_red()
board.add_blue()
board.render()
assert board.is_under_attack()
print('******** UNDER ATTACK ********')
